# %% [markdown]
# # Assignment 4

# %% [markdown]
# 1. What exactly is []?
#
# Ans - Lists are represented as [] in Python. [] denotes an empty list.
#
# 2. In a list of values stored in a variable called spam, how would you assign the value 'hello' as the third value?
#
# (Assume [2, 4, 6, 8, 10] are in spam.)
#
# Let's pretend the spam includes the list ['a', 'b', 'c', 'd'] for the next three queries.
#
# Ans - spam[2] = 'hello'
#
# 3. What is the value of spam[int(int('3' * 2) / 11)]?
#
# Ans- The value will be 'd'. It will search for spam[3] i.e 4th item in the list.
#
# 4. What is the value of spam[-1]?
#
# Ans - The value will be 'd'. Last item present in the list
#
# 5. What is the value of spam[:2]?
#
# Ans- The value will be ['a','b'].
#
# Let's pretend bacon has the list [3.14, 'cat,' 11, 'cat,' True] for the next three questions.
#
# 6. What is the value of bacon.index('cat')?
#
# Ans - The value will be 1.
#
#
# 7. How does bacon.append(99) change the look of the list value in bacon?
#
# Ans - The list will become [3.14, 'cat,' 11, 'cat,' True, 99]
#
#
# 8. How does bacon.remove('cat') change the look of the list in bacon?
#
# Ans - The list will become [3.14, 11,'cat,' True]. It will remove the first occurence of 'cat'.
#
# 9. What are the list concatenation and list replication operators?
#
# Ans - List concatenation operator is + . Eg , listA = [1,2] ,list B = [3, 4]. list A + list B will be [1,2,3,4]
#
#       List Replication Operator is *. Eg , listA = [1,2]. list A * 2 will be [1,2,1,2]
#
# 10. What is difference between the list methods append() and insert()?
#
# Ans - Append method will add the item to the end of the list whereas Insert method can be used to insert an item at a
#
#       specific index of the list.
#
#
# 11. What are the two methods for removing items from a list?
#
# Ans - The two methods for removing items from a list are pop() and remove().
#
# 12. Describe how list values and string values are identical.
#
# Ans - Both lists ans strings are ordered and can be accessed using the indices. Indexing and Slicing operations can be
#
#       applied to both lists and strings.
#
# 13. What's the difference between tuples and lists?
#
# Ans- Lists are mutable (i.e can be modified) whereas Tuples are immutable( i.e cannot be modified). Tuples consumes less memory
#
#      as compared to lists as they are stored in single block of memory.
#
# 14. How do you type a tuple value that only contains the integer 42?
#
# Ans - a = (42,).
#
# 15. How do you get a list value's tuple form? How do you get a tuple value's list form?
#
# Ans - List can be converted to tuple and tuples can be converted to list by typecasting.tuple() and list() function can be
#
#       used.
#
#       Eg. list1 = [1,2,3,4]
#
#           tuple1 = tuple(list1)
#
#       Eg. tuple2 = (1,2,3,4)
#
#           list2 = list(tuple2)
#
#
#
# 16. Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?
#
# Ans - They contain references to the values present in the lists.
#
#
# 17. How do you distinguish between copy.copy() and copy.deepcopy()?
#
# Ans - copy.copy , also known as shallow copy creates a copied object with references to the objects in the original object
#
#       which is copied. Modifying the copied object do change the original copy as well.
#
#       copy.deepcopy creates a new object which copies the main object recursively. Modifying the copied object will not
#
#       change the original copy.
